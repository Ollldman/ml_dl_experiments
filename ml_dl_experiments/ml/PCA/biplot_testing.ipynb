# %% [markdown]
# # PCA Biplot

# %%
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler

from ml_dl_experiments.ml.PCA.biplot import biplot

# %% [markdown]
# # IRIS example:

# %%
df_x, df_y = load_iris(return_X_y=True, as_frame=True)


scaler = StandardScaler()
X = scaler.fit_transform(df_x)

# %%
pca = PCA()
scores = pca.fit_transform(X)
df_scores = pd.DataFrame(
    scores, 
    columns=['PC'+ str(i) for i in range(1, df_x.shape[1] + 1)])
df_loadings = pd.DataFrame(
    pca.components_,
    columns=df_x.columns,
    index=df_scores.columns
)

# %%
df_scores.head()
# Out:
#         PC1       PC2       PC3       PC4
# 0 -2.264703  0.480027  0.127706 -0.024168
# 1 -2.080961 -0.674134  0.234609 -0.103007
# 2 -2.364229 -0.341908 -0.044201 -0.028377
# 3 -2.299384 -0.597395 -0.091290  0.065956
# 4 -2.389842  0.646835 -0.015738  0.035923

# %%
df_loadings.head()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# PC1           0.521066         -0.269347           0.580413          0.564857
# PC2           0.377418          0.923296           0.024492          0.066942
# PC3           0.719566         -0.244382          -0.142126         -0.634273
# PC4          -0.261286          0.123510           0.801449         -0.523597

# %%
biplot(df_scores, df_loadings)
